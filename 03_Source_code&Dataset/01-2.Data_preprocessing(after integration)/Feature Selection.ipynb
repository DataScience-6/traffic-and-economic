# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
#  In class, SelectKBest was learned as a Classifier,
# but our dataset was close to Regression and proceeded with Regression

# 'f_regression' : tatistical method used in feature selection during the
# pre-processing phase of machine learning

# 'ExtraTreesRegressor' : "Extremely Randomized Trees Regressor" and is part of the ensemble methods

# %%
# Load the dataset
data = pd.read_csv("../00_Data/Integrated_data/Integration_b.csv",encoding="utf-8")
data.dropna(inplace=True)

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Fit ExtraTreesRegressor on the selected features
# n_estimators : the  number of trees in the forest
# criterion : the function to measure the quality of a split.
# random_state  : affects the randomness of the bootstrapping of the samples
model = ExtraTreesRegressor(n_estimators=100, random_state=42)
model.fit(X_train_selected, y_train)

# Print the selected features and their importance
selected_features = X.columns[selector.get_support()]
feature_importances = model.feature_importances_

# Display the selected features and their importances
selected_features_df = pd.DataFrame({
    'Feature': selected_features,
    'Importance': feature_importances
})
selected_features_df
# Out:
#                            Feature  Importance
# 0                    Exchange Rate    0.055639
# 1     Gross Domestic Product (GDP)    0.331920
# 2               Export growth rate    0.046158
# 3               Import growth rate    0.045371
# 4  Nationwide Consumer Price Index    0.170285
# 5        Regular Unleaded Gasoline    0.052065
# 6      Diesel Fuel for Automobiles    0.047411
# 7          number of car ownership    0.251151

# %%
# Plotting feature importances
plt.figure(figsize=(10, 6))
plt.title('Feature Importances')
plt.barh(selected_features, feature_importances, color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
# GDP  has the highest feature importance

# And number of car ownership and Nationwide Consumer Price Index have meaningful value
