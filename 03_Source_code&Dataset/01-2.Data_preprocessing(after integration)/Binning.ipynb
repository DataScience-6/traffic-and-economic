# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load dataest
data = pd.read_csv('../00_Data/Integrated_data/Fully_integrated_data.csv')
data.head()
# Out:
#    Unnamed: 0        Date  Total Traffic Volume  Base Interest Rate  \
# 0           0  2011-01-01             5466446.0                2.75
# 1           1  2011-01-02             5059821.0                2.75
# 2           2  2011-01-03             5631394.0                2.75
# 3           3  2011-01-04             5584995.0                2.75
# 4           4  2011-01-05             5742955.0                2.75
#
#    Exchange Rate  Gross Domestic Product (GDP)  \
# 0    1121.500000                      328096.0
# 1    1121.732258                      328096.0
# 2    1121.964516                      328096.0
# 3    1122.196774                      328096.0
# 4    1122.429032                      328096.0
#
#    Economic Growth Rate (Real GDP Growth Rate)  Export price  \
# 0                                          5.4   44465366.00
# 1                                          5.4   44269519.60
# 2                                          5.4   44073673.20
# ...

# %%
#  Define categories for economic growth
bins = [-float('inf'), 0, 2, 4, float('inf')]
labels = ['Negative Growth', 'Low Growth', 'Moderate Growth', 'High Growth']

# Dividing economic growth rates into categories
data['Economic Growth Rate'] = pd.cut(data['Economic Growth Rate (Real GDP Growth Rate)'], bins=bins, labels=labels)

#pd.cut : a function in the pandas library used to segment and sort data values into bins
# x : array-like input data
# bins : Can be an integer specifying the number of equal-width bins
data
# Out:
#       Unnamed: 0        Date  Total Traffic Volume  Base Interest Rate  \
# 0              0  2011-01-01             5466446.0                2.75
# 1              1  2011-01-02             5059821.0                2.75
# 2              2  2011-01-03             5631394.0                2.75
# 3              3  2011-01-04             5584995.0                2.75
# 4              4  2011-01-05             5742955.0                2.75
# ...          ...         ...                   ...                 ...
# 4741        4741  2023-12-27            10276694.0                3.50
# 4742        4742  2023-12-28            10408581.0                3.50
# 4743        4743  2023-12-29            11018411.0                3.50
# 4744        4744  2023-12-30             8958402.0                3.50
# 4745        4745  2023-12-31             7891390.0                3.50
#
#       Exchange Rate  Gross Domestic Product (GDP)  \
# 0       1121.500000                      328096.0
# ...

# %%
# 'Economic Growth Rate (Real GDP Growth Rate)' Remove a Column
data.drop('Economic Growth Rate (Real GDP Growth Rate)', axis=1, inplace=True)

# %%
data
# Out:
#       Unnamed: 0        Date  Total Traffic Volume  Base Interest Rate  \
# 0              0  2011-01-01             5466446.0                2.75
# 1              1  2011-01-02             5059821.0                2.75
# 2              2  2011-01-03             5631394.0                2.75
# 3              3  2011-01-04             5584995.0                2.75
# 4              4  2011-01-05             5742955.0                2.75
# ...          ...         ...                   ...                 ...
# 4741        4741  2023-12-27            10276694.0                3.50
# 4742        4742  2023-12-28            10408581.0                3.50
# 4743        4743  2023-12-29            11018411.0                3.50
# 4744        4744  2023-12-30             8958402.0                3.50
# 4745        4745  2023-12-31             7891390.0                3.50
#
#       Exchange Rate  Gross Domestic Product (GDP)  Export price  \
# ...

# %%
# 'Check the basic statistics of 'Base Interest Rate'
data['Base Interest Rate'].describe()
# Out:
# count    4746.000000
# mean        1.954277
# std         0.920133
# min         0.500000
# 25%         1.250000
# 50%         1.750000
# 75%         2.750000
# max         3.500000
# Name: Base Interest Rate, dtype: float64

# %%
# Define categories for interest rates
#(categories are illustrated as examples and must be adapted for actual data)
bins = [0, 3.0, 5.0, float('inf')]
labels = ['Low', 'Moderate', 'High']

# Divide interest rates into categories
data['Interest Rate Category'] = pd.cut(data['Base Interest Rate'], bins=bins, labels=labels)

# Remove the original 'Base Interest Rate' column
data.drop('Base Interest Rate', axis=1, inplace=True)

# %%
data
# Out:
#       Unnamed: 0        Date  Total Traffic Volume  Exchange Rate  \
# 0              0  2011-01-01             5466446.0    1121.500000
# 1              1  2011-01-02             5059821.0    1121.732258
# 2              2  2011-01-03             5631394.0    1121.964516
# 3              3  2011-01-04             5584995.0    1122.196774
# 4              4  2011-01-05             5742955.0    1122.429032
# ...          ...         ...                   ...            ...
# 4741        4741  2023-12-27            10276694.0    1324.077419
# 4742        4742  2023-12-28            10408581.0    1325.580645
# 4743        4743  2023-12-29            11018411.0    1327.083871
# 4744        4744  2023-12-30             8958402.0    1328.587097
# 4745        4745  2023-12-31             7891390.0    1330.090323
#
#       Gross Domestic Product (GDP)  Export price  Export growth rate  \
# 0                         328096.0   44465366.00           44.700000
# ...

# %%
data['Import price'].describe()
# Out:
# count    4.746000e+03
# mean     4.450010e+07
# std      7.400966e+06
# min      2.917560e+07
# 25%      3.947231e+07
# 50%      4.373185e+07
# 75%      4.709192e+07
# max      6.602562e+07
# Name: Import price, dtype: float64

# %%
data['Export price'].describe()
# Out:
# count    4.746000e+03
# mean     4.773877e+07
# std      5.075206e+06
# min      3.485869e+07
# 25%      4.465773e+07
# 50%      4.701549e+07
# 75%      5.076134e+07
# max      6.375929e+07
# Name: Export price, dtype: float64

# %%
# Draw a histogram
plt.figure(figsize=(12, 6))

# Export price histogram
plt.subplot(1, 2, 1)
plt.hist(data['Export price'], bins=30, color='blue', alpha=0.7)
plt.title('Export Price Distribution')
plt.xlabel('Export Price')
plt.ylabel('Frequency')

# Import price histogram
plt.subplot(1, 2, 2)
plt.hist(data['Import price'], bins=30, color='green', alpha=0.7)
plt.title('Import Price Distribution')
plt.xlabel('Import Price')

plt.tight_layout()
plt.show()

# %%
# EDivide the export price and import price into 
# four equal frequency intervals, respectively
data['Export Price Category'] = pd.qcut(data['Export price'], 4, labels=['Low', 'Medium', 'High', 'Very High'])
data['Import Price Category'] = pd.qcut(data['Import price'], 4, labels=['Low', 'Medium', 'High', 'Very High'])
# pd.qcut : uses quantiles to divide the data.
# This method ensures that each bin has roughly the same number of data points
# x: The one-dimensional input array or series to be binned.
# q: The number of quantiles. 
# labels: Optionally, labels for the bins
# Result Screen
print(data[['Export price', 'Export Price Category', 'Import price', 'Import Price Category']].head())
# Out:
#    Export price Export Price Category  Import price Import Price Category
# 0   44465366.00                   Low   41981323.00                Medium
# 1   44269519.60                   Low   41799132.37                Medium
# 2   44073673.20                   Low   41616941.74                Medium
# 3   43877826.79                   Low   41434751.11                Medium
# 4   43681980.39                   Low   41252560.48                Medium

# %%
#Remove the original price column
data.drop(['Export price', 'Import price'], axis=1, inplace=True)

# %%
data
# Out:
#       Unnamed: 0        Date  Total Traffic Volume  Exchange Rate  \
# 0              0  2011-01-01             5466446.0    1121.500000
# 1              1  2011-01-02             5059821.0    1121.732258
# 2              2  2011-01-03             5631394.0    1121.964516
# 3              3  2011-01-04             5584995.0    1122.196774
# 4              4  2011-01-05             5742955.0    1122.429032
# ...          ...         ...                   ...            ...
# 4741        4741  2023-12-27            10276694.0    1324.077419
# 4742        4742  2023-12-28            10408581.0    1325.580645
# 4743        4743  2023-12-29            11018411.0    1327.083871
# 4744        4744  2023-12-30             8958402.0    1328.587097
# 4745        4745  2023-12-31             7891390.0    1330.090323
#
#       Gross Domestic Product (GDP)  Export growth rate  Import growth rate  \
# 0                         328096.0           44.700000           13.600000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       4746 non-null   int64
#  1   Date                             4746 non-null   object
#  2   Total Traffic Volume             4746 non-null   float64
#  3   Exchange Rate                    4746 non-null   float64
#  4   Gross Domestic Product (GDP)     4746 non-null   float64
#  5   Export growth rate               4746 non-null   float64
#  6   Import growth rate               4746 non-null   float64
#  7   Nationwide Consumer Price Index  4746 non-null   float64
#  8   Regular Unleaded Gasoline        4746 non-null   float64
#  9   Diesel Fuel for Automobiles      4746 non-null   float64
#  10  number of car ownership          4746 non-null   int64
# ...

# %%
data.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
data.to_csv('../00_Data/Integrated_data/integration_b.csv',index=False)
