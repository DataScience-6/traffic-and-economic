# %%
# !pip list
# Out:
# Package             Version
# ------------------- -----------
# asttokens           2.4.1
# certifi             2024.2.2
# charset-normalizer  3.3.2
# click               8.1.7
# cloudpickle         3.0.0
# colorama            0.4.6
# comm                0.2.2
# contourpy           1.2.0
# CSIKit              2.5
# cycler              0.12.1
# dask                2024.4.0
# dask-expr           1.0.6
# debugpy             1.8.1
# decorator           5.1.1
# distributed         2024.4.0
# et-xmlfile          1.1.0
# executing           2.0.1
# featuretools        1.30.0
# fonttools           4.50.0
# fsspec              2024.3.1
# holidays            0.46
# idna                3.6
# importlib_resources 6.4.0
# ipykernel           6.29.4
# ipython             8.25.0
# jedi                0.19.1
# Jinja2              3.1.3
# joblib              1.3.2
# jupyter_client      8.6.2
# jupyter_core        5.7.2
# kiwisolver          1.4.5
# locket              1.0.0
# ...

# %%
import featuretools as ft
import pandas as pd

# %%
data=pd.read_csv("../00_Data/Integrated_data/integration_b.csv",encoding="utf-8")
data.head()
# Out:
#          Date  Total Traffic Volume  Exchange Rate  \
# 0  2011-01-01             5466446.0    1121.500000
# 1  2011-01-02             5059821.0    1121.732258
# 2  2011-01-03             5631394.0    1121.964516
# 3  2011-01-04             5584995.0    1122.196774
# 4  2011-01-05             5742955.0    1122.429032
#
#    Gross Domestic Product (GDP)  Export growth rate  Import growth rate  \
# 0                      328096.0           44.700000           13.600000
# 1                      328096.0           43.775943           13.521635
# 2                      328096.0           42.851885           13.443269
# 3                      328096.0           41.927828           13.364904
# 4                      328096.0           41.003771           13.286539
#
#    Nationwide Consumer Price Index  Regular Unleaded Gasoline  \
# 0                        90.448000                    1814.57
# 1                        90.397806                    1815.24
# ...

# %%
# Create an entity set
es = ft.EntitySet(id='economic_data')

# Add the data as an entity
es = es.add_dataframe(dataframe_name='data', dataframe=data, index='index', make_index=True)

# Run deep feature synthesis (DFS) to create new features
feature_matrix, feature_defs = ft.dfs(
    entityset=es,
    target_dataframe_name='data',
    agg_primitives=['mean', 'sum', 'min', 'max', 'std','count'],
    trans_primitives=['month', 'year', 'diff'],
    max_depth=5) 

feature_matrix.head()
# Out:
# c:\Python312\Lib\site-packages\woodwork\type_sys\utils.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# c:\Python312\Lib\site-packages\woodwork\type_sys\utils.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# c:\Python312\Lib\site-packages\woodwork\type_sys\utils.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# ...

# %%
print([f.get_name() for f in feature_defs])
# Out:
# ['Total Traffic Volume', 'Exchange Rate', 'Gross Domestic Product (GDP)', 'Export growth rate', 'Import growth rate', 'Nationwide Consumer Price Index', 'Regular Unleaded Gasoline', 'Diesel Fuel for Automobiles', 'number of car ownership', 'Economic Growth Rate', 'Interest Rate Category', 'Export Price Category', 'Import Price Category', 'DIFF(Diesel Fuel for Automobiles)', 'DIFF(Exchange Rate)', 'DIFF(Export growth rate)', 'DIFF(Gross Domestic Product (GDP))', 'DIFF(Import growth rate)', 'DIFF(Nationwide Consumer Price Index)', 'DIFF(Regular Unleaded Gasoline)', 'DIFF(Total Traffic Volume)', 'DIFF(number of car ownership)', 'MONTH(Date)', 'YEAR(Date)']
